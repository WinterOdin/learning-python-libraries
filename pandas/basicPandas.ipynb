# %%
import pandas as pd

df = pd.read_csv("master.csv")
country_df = df[df['country'] == "Poland"]
#country_index = country_df.set_index("year")
#country_index.sort_index(inplace=True)
#country_index["suicides_no"].rolling(25).mean().plot()
sum_suicides = country_df.groupby("year")["suicides_no"].sum()
countires = df['country'].unique()
sum_years = df.groupby(["year"])["suicides_no"].sum()
sum_years.plot()
# Out:
# <AxesSubplot:xlabel='year'>
